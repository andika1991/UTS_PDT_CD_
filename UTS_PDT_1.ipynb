# %% [markdown]
# ##Data penjualan alpukat di pasar AS

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/andika1991/UTS_PDT_CD_/main/avocado.csv")
df.head()
# Out:
#          Date  AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  \
# 0  27/12/2015          1.33      64236.62     8696.87     8603.62       93.25
# 1  20/12/2015          1.35      54876.98     9505.56     9408.07       97.49
# 2  13/12/2015          0.93     118220.22     8145.35     8042.21      103.14
# 3  06/12/2015          1.08      78992.15     5811.16     5677.40      133.76
# 4  29/11/2015          1.28      51039.60     6183.95     5986.26      197.69
#
#    XLarge Bags          type  year  region
# 0          0.0  conventional  2015  Albany
# 1          0.0  conventional  2015  Albany
# 2          0.0  conventional  2015  Albany
# 3          0.0  conventional  2015  Albany
# 4          0.0  conventional  2015  Albany

# %%
total_volume = df["Total Volume"].sum()
median_volume = df["Total Volume"].median()
mean_volume = df["Total Volume"].mean()

total_bags = df["Total Bags"].sum()
median_bags = df["Total Bags"].median()
mean_bags = df["Total Bags"].mean()

mean_avg_price = df["AveragePrice"].mean()
median_avg_price = df["AveragePrice"].median()

print("Total Volume:", total_volume)
print("Median Volume:", median_volume)
print("Mean Volume:", mean_volume)

print("Total Bags:", total_bags)
print("Median Bags:", median_bags)
print("Mean Bags:", mean_bags)
# Out:
# Total Volume: 15523402593.400002
# Median Volume: 107376.76
# Mean Volume: 850644.0130089321
# Total Bags: 4373175798.389999
# Median Bags: 39743.83
# Mean Bags: 239639.20205983886
